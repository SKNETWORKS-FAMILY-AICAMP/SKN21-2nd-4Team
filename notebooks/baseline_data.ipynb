# %%
import pandas as pd
import os

paths = [
    # "/Users/anhyebin/Documents/SKN21/SKN21-2nd-4Team/data/interim/Customer_Churn_Dataset_0_impute.csv",
    "/Users/anhyebin/Documents/SKN21/SKN21-2nd-4Team/data/interim/Customer_Churn_Dataset_knn.csv",
    "/Users/anhyebin/Documents/SKN21/SKN21-2nd-4Team/data/interim/Customer_Churn_Dataset_simple_frequent.csv",
    "/Users/anhyebin/Documents/SKN21/SKN21-2nd-4Team/data/interim/Customer_Churn_Dataset_simple_median.csv"
]

output_path = '/Users/anhyebin/Documents/SKN21/SKN21-2nd-4Team/data/processed'

# %%
#범주형 컬럼 매핑
binary_mapping = {
    'Yes': 1,
    'No': 0,
    'Male': 1,
    'Female': 0,
    'No internet service': 0,
    'No phone service': 0
}


# #범주형 컬럼
categorical_cols = [
    'gender', 'Partner', 'Dependents', 'PhoneService', 'MultipleLines', 
    'InternetService', 'OnlineSecurity', 'OnlineBackup', 'DeviceProtection',
    'TechSupport', 'StreamingTV', 'StreamingMovies', 'Contract', 
    'PaperlessBilling', 'PaymentMethod', 'Churn'
]


for path in paths:
    df = pd.read_csv(path)


    df = df.drop(columns = ["customerID"])

    for col in categorical_cols:
        df[col] = df[col].map(binary_mapping).fillna(df[col])

    

    file_name = os.path.basename(path).replace(".csv", "_baseline.csv")
    save_path = os.path.join(output_path, file_name)


    df.to_csv(save_path,index = False)
    print(f"{save_path} 저장 완료")
# Out:
# /Users/anhyebin/Documents/SKN21/SKN21-2nd-4Team/data/processed/Customer_Churn_Dataset_knn_baseline.csv 저장 완료
# /Users/anhyebin/Documents/SKN21/SKN21-2nd-4Team/data/processed/Customer_Churn_Dataset_simple_frequent_baseline.csv 저장 완료
# /Users/anhyebin/Documents/SKN21/SKN21-2nd-4Team/data/processed/Customer_Churn_Dataset_simple_median_baseline.csv 저장 완료

# %%
df.info
# Out:
# <bound method DataFrame.info of       Unnamed: 0  gender  SeniorCitizen  Partner  Dependents  tenure  \
# 0              0       0              0        1           0       1
# 1              1       1              0        0           0      34
# 2              2       1              0        0           0       2
# 3              3       1              0        0           0      45
# 4              4       0              0        0           0       2
# ...          ...     ...            ...      ...         ...     ...
# 7038        7038       1              0        1           1      24
# 7039        7039       0              0        1           1      72
# 7040        7040       0              0        1           1      11
# 7041        7041       1              1        1           0       4
# 7042        7042       1              0        0           0      66
#
#       PhoneService  MultipleLines InternetService  OnlineSecurity  ...  \
# ...
